# %%
import pandas as pd

# Try UTF-8 first
df = pd.read_csv("french_data.csv", encoding="utf-8")

# %%
import chardet

with open("french_data.csv", "rb") as f:
    rawdata = f.read(10000)  # read a chunk
    result = chardet.detect(rawdata)
    print(result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.8230280000000001, 'language': 'fr', 'mime_type': 'text/plain'}

# %%
print(df["text"].head(10))
# Out:
# 0     Ma valeur transcende mes moments sombres
# 1    Je mérite de vivre pleinement chaque jour
# 2     Ma valeur transcende mes moments sombres
# 3               Je mérite de vivre, pour vrai!
# 4                Je mérite de vivre pleinement
# 5               Je mérite de vivre chaque jour
# 6               Je mérite de vivre chaque jour
# 7    Je mérite de vivre pleinement chaque jour
# 8        La vie mérite d'être vécue pleinement
# 9                Je mérite de vivre pleinement
# Name: text, dtype: object
